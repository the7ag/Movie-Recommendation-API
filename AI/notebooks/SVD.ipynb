# %% [markdown]
# # SVD

# %%
# !unzip "ratings.zip"
# Out:
# Archive:  ratings.zip
# replace ratings.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
import pandas as pd

df = pd.read_csv('ratings.csv')
df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        1     4.0  1225734739
# 1       1      110     4.0  1225865086
# 2       1      158     4.0  1225733503
# 3       1      260     4.5  1225735204
# 4       1      356     5.0  1225735119

# %%
len(df)
# Out:
# 33832162

# %%
df.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  3.383216e+07  3.383216e+07  3.383216e+07  3.383216e+07
# mean   1.654380e+05  2.831348e+04  3.542540e+00  1.269362e+09
# std    9.534122e+04  4.992865e+04  1.063959e+00  2.541023e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    8.295300e+04  1.219000e+03  3.000000e+00  1.046718e+09
# 50%    1.661290e+05  3.263000e+03  4.000000e+00  1.264740e+09
# 75%    2.474500e+05  4.049100e+04  4.000000e+00  1.496919e+09
# max    3.309750e+05  2.889830e+05  5.000000e+00  1.689843e+09

# %%
num_users = len(df['userId'].unique())
num_movies = len(df['movieId'].unique())

num_users, num_movies
# Out:
# (330975, 83239)

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /opt/conda/lib/python3.10/site-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.11.4)

# %%
import gc
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split

# %%
# Get the list of all movie IDs
all_movie_ids = df['movieId'].unique()
print(len(all_movie_ids))

# Get the list of movies that user 1 has not watched
watched_movies = df[df['userId'] == 1]['movieId']
unwatched_movies = [movie_id for movie_id in all_movie_ids if movie_id not in watched_movies]
print(len(unwatched_movies))
# Out:
# 83239
# 83178

# %%
# Define a Reader object to parse the ratings
reader = Reader(rating_scale=(0.5, 5))

# Load the data into the Surprise Dataset format
data = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)

del df

# %%
gc.collect()
# Out:
# 30

# %%
# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

del data

# %%
gc.collect()
# Out:
# 0

# %%
# Initialize the SVD algorithm
algo = SVD()

# Train the algorithm on the training set
algo.fit(trainset)

# %%
# Make predictions for the unwatched movies
predictions = [algo.predict(1, movie_id) for movie_id in unwatched_movies]

# Sort the predictions by estimated rating in descending order
sorted_predictions = sorted(predictions, key=lambda x: x.est, reverse=True)

# %%
# Print the top N recommendations
top_n = 100
print(f"Top {top_n} Recommendations for User 1:")
for i, pred in enumerate(sorted_predictions[:top_n]):
    movie_id = pred.iid
    movie_rating = pred.est
    print(f"#{i+1}: Movie ID {movie_id}, Predicted Rating: {movie_rating}")
# Out:
# Top 100 Recommendations for User 1:
# #1: Movie ID 122912, Predicted Rating: 4.87011927742651
# #2: Movie ID 122914, Predicted Rating: 4.823283162352283
# #3: Movie ID 261955, Predicted Rating: 4.696020625085525
# #4: Movie ID 7153, Predicted Rating: 4.683374477233732
# #5: Movie ID 6539, Predicted Rating: 4.6822581657920965
# #6: Movie ID 318, Predicted Rating: 4.678484395121456
# #7: Movie ID 228881, Predicted Rating: 4.621061738928383
# #8: Movie ID 58376, Predicted Rating: 4.617607611986646
# #9: Movie ID 122916, Predicted Rating: 4.614038600600312
# #10: Movie ID 147326, Predicted Rating: 4.604009969937634
# #11: Movie ID 88125, Predicted Rating: 4.592002569515453
# #12: Movie ID 45722, Predicted Rating: 4.584026876307281
# #13: Movie ID 1721, Predicted Rating: 4.58310192867858
# #14: Movie ID 117555, Predicted Rating: 4.579241599651569
# #67: Movie ID 130510, Predicted Rating: 4.473620203027679
# #68: Movie ID 5989, Predicted Rating: 4.473253830032522
# #69: Movie ID 457, Predicted Rating: 4.472343141762372
# #70: Movie ID 115617, Predicted Rating: 4.467374563518716
# #71: Movie ID 3948, Predicted Rating: 4.464680696519835
# #72: Movie ID 1923, Predicted Rating: 4.4646536400478825
# #73: Movie ID 102903, Predicted Rating: 4.464368916261473
# #74: Movie ID 192001, Predicted Rating: 4.464109918251903
# #75: Movie ID 54259, Predicted Rating: 4.462873389566399
# #76: Movie ID 134130, Predicted Rating: 4.4587425690594635
# #77: Movie ID 4995, Predicted Rating: 4.455806370071525
# #78: Movie ID 128872, Predicted Rating: 4.453322434591589
# #79: Movie ID 69844, Predicted Rating: 4.452283028423672
# #80: Movie ID 76093, Predicted Rating: 4.450453871083252
# #81: Movie ID 118696, Predicted Rating: 4.4488517174706
# #82: Movie ID 131586, Predicted Rating: 4.44811114766945
# #83: Movie ID 231341, Predicted Rating: 4.4468716125485965
# #84: Movie ID 119145, Predicted Rating: 4.445814080838865
# #85: Movie ID 4306, Predicted Rating: 4.443774949607262
# #86: Movie ID 8972, Predicted Rating: 4.443376628293902
# #87: Movie ID 182723, Predicted Rating: 4.4431673277196575
# #88: Movie ID 40815, Predicted Rating: 4.442818550067712
# #89: Movie ID 165421, Predicted Rating: 4.439403965127746
# #90: Movie ID 226258, Predicted Rating: 4.4381877156574365
# #91: Movie ID 91529, Predicted Rating: 4.437905299699122
# #92: Movie ID 88810, Predicted Rating: 4.435454839902218
# #93: Movie ID 195529, Predicted Rating: 4.434893601190573
# #94: Movie ID 109487, Predicted Rating: 4.434088159179852
# #95: Movie ID 122282, Predicted Rating: 4.434034451520187
# #96: Movie ID 5064, Predicted Rating: 4.433194832435575
# #97: Movie ID 158807, Predicted Rating: 4.432917511201893
# #98: Movie ID 109889, Predicted Rating: 4.432827832831611
# #99: Movie ID 275515, Predicted Rating: 4.431963904312048
# #100: Movie ID 122904, Predicted Rating: 4.431800426606251

# %%
from surprise.dump import dump

# Save the trained model
dump_file = 'trained_model.dump'
dump(dump_file, algo=algo)

# %%
from surprise.dump import load

# Load the trained model from the dump file
loaded_model = load(dump_file)[1]

# Make recommendations using the loaded model
predictions = [loaded_model.predict(1, movie_id) for movie_id in unwatched_movies]

# Sort the predictions by estimated rating in descending order
sorted_predictions = sorted(predictions, key=lambda x: x.est, reverse=True)

# Print the top N recommendations
top_n = 100
print(f"Top {top_n} Recommendations for User 1 using the loaded model:")
for i, pred in enumerate(sorted_predictions[:top_n]):
    movie_id = pred.iid
    movie_rating = pred.est
    print(f"#{i+1}: Movie ID {movie_id}, Predicted Rating: {movie_rating}")
# Out:
# Top 100 Recommendations for User 1 using the loaded model:
# #1: Movie ID 122912, Predicted Rating: 4.87011927742651
# #2: Movie ID 122914, Predicted Rating: 4.823283162352283
# #3: Movie ID 261955, Predicted Rating: 4.696020625085525
# #4: Movie ID 7153, Predicted Rating: 4.683374477233732
# #5: Movie ID 6539, Predicted Rating: 4.6822581657920965
# #6: Movie ID 318, Predicted Rating: 4.678484395121456
# #58: Movie ID 73881, Predicted Rating: 4.48249542536799
# #59: Movie ID 154474, Predicted Rating: 4.479824347557791
# #60: Movie ID 166643, Predicted Rating: 4.479087304022473
# #61: Movie ID 101685, Predicted Rating: 4.478714232380034
# #62: Movie ID 194448, Predicted Rating: 4.476294655281378
# #63: Movie ID 89745, Predicted Rating: 4.475899537447872
# #64: Movie ID 152081, Predicted Rating: 4.474851308978376
# #65: Movie ID 174703, Predicted Rating: 4.474731327038963
# #66: Movie ID 166920, Predicted Rating: 4.47436268864568
# #67: Movie ID 130510, Predicted Rating: 4.473620203027679
# #68: Movie ID 5989, Predicted Rating: 4.473253830032522
# #69: Movie ID 457, Predicted Rating: 4.472343141762372
# #70: Movie ID 115617, Predicted Rating: 4.467374563518716
# #71: Movie ID 3948, Predicted Rating: 4.464680696519835
# #72: Movie ID 1923, Predicted Rating: 4.4646536400478825
# #73: Movie ID 102903, Predicted Rating: 4.464368916261473
# #74: Movie ID 192001, Predicted Rating: 4.464109918251903
# #75: Movie ID 54259, Predicted Rating: 4.462873389566399
# #76: Movie ID 134130, Predicted Rating: 4.4587425690594635
# #77: Movie ID 4995, Predicted Rating: 4.455806370071525
# #78: Movie ID 128872, Predicted Rating: 4.453322434591589
# #79: Movie ID 69844, Predicted Rating: 4.452283028423672
# #80: Movie ID 76093, Predicted Rating: 4.450453871083252
# #81: Movie ID 118696, Predicted Rating: 4.4488517174706
# #82: Movie ID 131586, Predicted Rating: 4.44811114766945
# #83: Movie ID 231341, Predicted Rating: 4.4468716125485965
# #84: Movie ID 119145, Predicted Rating: 4.445814080838865
# #85: Movie ID 4306, Predicted Rating: 4.443774949607262
# #86: Movie ID 8972, Predicted Rating: 4.443376628293902
# #87: Movie ID 182723, Predicted Rating: 4.4431673277196575
# #88: Movie ID 40815, Predicted Rating: 4.442818550067712
# #89: Movie ID 165421, Predicted Rating: 4.439403965127746
# #90: Movie ID 226258, Predicted Rating: 4.4381877156574365
# #91: Movie ID 91529, Predicted Rating: 4.437905299699122
# #92: Movie ID 88810, Predicted Rating: 4.435454839902218
# #93: Movie ID 195529, Predicted Rating: 4.434893601190573
# #94: Movie ID 109487, Predicted Rating: 4.434088159179852
# #95: Movie ID 122282, Predicted Rating: 4.434034451520187
# #96: Movie ID 5064, Predicted Rating: 4.433194832435575
# #97: Movie ID 158807, Predicted Rating: 4.432917511201893
# #98: Movie ID 109889, Predicted Rating: 4.432827832831611
# #99: Movie ID 275515, Predicted Rating: 4.431963904312048
# #100: Movie ID 122904, Predicted Rating: 4.431800426606251

# %%
def accuracy(y_true, y_pred, threshold=0.25):
    correct = [abs(true - pred) < threshold for true, pred in zip(y_true, y_pred)]
    return sum(correct) / len(correct)

# Get true ratings from the test set
true_ratings = [rating for (_, _, rating) in testset]

# Predict ratings using the model
predicted_ratings = [algo.predict(uid, iid).est for (uid, iid, _) in testset]

# Calculate accuracy
acc = accuracy(true_ratings, predicted_ratings)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.29619771599009403

# %%
acc = accuracy(true_ratings, predicted_ratings, threshold=0.5)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.5374153560672218

# %% [markdown]
# ---
